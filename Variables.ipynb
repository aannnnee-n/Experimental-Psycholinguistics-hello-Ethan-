# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
today = "friday"
type(today)
# Out:
# str

# %% [markdown]
# ## Integers

# %%
week = 37
type(week)
# Out:
# int

# %% [markdown]
# ## Floats

# %%
time = 8.5
type(time)
# Out:
# float

# %% [markdown]
# ## Lists

# %%
myVariables = [3, 2, 78, 2]

# %% [markdown]
# lists are ordered and so we can call items from their ordered position

# %%
myVariables[1]
# Out:
# 2

# %% [markdown]
# python counts from 0 (jst like stories in a house). some programming Lscounts from 1

# %%
myVariables[0]
# Out:
# 3

# %% [markdown]
# you can also change the items of the list

# %%
myVariables[1]=5
myVariables
# Out:
# [3, 5, 78, 2]

# %%
yourVariables = [today, week, time]
yourVariables
# Out:
# ['friday', 37, 8.5]

# %%
yourVariables
# Out:
# ['friday', 37, 8.5]

# %% [markdown]
# ## Tuples

# %%
shopping_list = ["apples", "pears", "bananas"]
shopping_tuple = ("apples", "pears", "bananas")

# %%
shopping_list[1]
# Out:
# 'pears'

# %%
shopping_list[2]
# Out:
# 'bananas'

# %%
shopping_list[1] = "grapes"
shopping_list
# Out:
# ['apples', 'grapes', 'bananas']

# %%
shopping_tuple[1] = "grapes"
shopping_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 shopping_tuple[1] = "grapes"
#       2 shopping_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# you get an error bc tuples are unchangeable

# %% [markdown]
# ## Sets

# %%
newList = [4, 4, 7, 19, 21, "im a string", "aa", 7.23]
mySet = set(newList)
mySet
# Out:
# {19, 21, 4, 7, 7.23, 'aa', 'im a string'}

# %% [markdown]
# sets are unordered, and can have no duplicate members. python seems to order sets by lowest number and then alphabet (21 is lower than four bc python looks at 2 vs. 4).

# %% [markdown]
# the len() counts the number of items.
#
# you can also make sets like this:

# %%
myNextSet = {3, 5, 7}
myNextSet
# Out:
# {3, 5, 7}

# %% [markdown]
# ## Dictionaries

# %%
my_pet = {'name': 'D2',
         'species': 'cat',
         'likes': 'sleeping',
         'dislikes': 'loud noises',
         'age': 10}

# %% [markdown]
# here items are separated by a colon: {key:value}

# %%
my_pet["age"]
# Out:
# 10

# %%
my_pet["likes"]
# Out:
# 'sleeping'

# %%
items = ['grapes', 'skyr', 'milk', 'rice']
number = [1, 2, 7, 3]
priority = ['high', 'high', 'low', 'high']

# %%
shopping = {'items': items,
            'number': number,
            'priority': priority}

# %%
shopping['items']
# Out:
# ['grapes', 'skyr', 'milk', 'rice']

# %%
shopping['items'] [2]
# Out:
# 'milk'

# %% [markdown]
# you can also make lists inside lists. this embedded list will also count as an item.

# %%
body = [['sweater', 'tshirt'], 'jeans', ['socks', 'shoes']]
head = ['curls', 'bobby pins']
hands = ['rings', 'bracelet']

# %%
outfit = {'clothes': clothes,
          'hair': hair,
          'accessories': accessories}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 outfit = {'clothes': clothes,
#       2           'hair': hair,
#       3           'accessories': accessories}
#
# NameError: name 'clothes' is not defined

# %%
outfit['accessories']
#here I get python to show me the list connected to 'hands'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 outfit['accessories']
#       2 #here I get python to show me the list connected to 'hands'
#
# NameError: name 'outfit' is not defined

# %%
outfit['clothes'][0][0]
#here I get python to show me the first item in the first embedded item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 outfit['clothes'][0][0]
#       2 #here I get python to show me the first item in the first embedded item
#
# NameError: name 'outfit' is not defined

# %% [markdown]
# ## function len()

# %%
a = [4, 5, 6, 7, 8, 9, 10, 55]

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 8

# %%
b = 'i am a string!'
len(b)
# Out:
# 14

# %% [markdown]
# slicing:

# %%
a[3:5]
# Out:
# [7, 8]

# %%
a[3:]
# Out:
# [7, 8, 9, 10, 55]

# %% [markdown]
# negative indexing: when you count the places in the list from the end, so:

# %%
a[-1]
# Out:
# 55

# %% [markdown]
# -1 is the last item on the list

# %% [markdown]
# ## dataframes

# %% [markdown]
# there exists this package/module/library called pandas.
#
# it is not part of the standard python-library.
#
# we can install this module on our computer, and then we can import the library in to all our files.
#
# so, you don't need to install it every time, but you need to import it for every new file you make.
#
# (pandas is already installed in jupyter tho)

# %%
import pandas as pd

# %% [markdown]
# "as pd" assigns a name for pandas that we have decided on.
#
# pd is the standard shortened version for pandas, so use that.

# %% [markdown]
# making a dataframe:

# %%
a = [3, 4, 78, 6]
b = [43, 42, 178, 76]
c = [38, 45, 728, 46]

# %% [markdown]
# pandas insist upon having equal rows and columns in a dataframe

# %%
arla = pd.DataFrame({'a': a, 'b': b,'c': c})

# %% [markdown]
# .DataFrame is a function that pandas has

# %%
type(arla)
# Out:
# pandas.DataFrame

# %%
arla
# Out:
#     a    b    c
# 0   3   43   38
# 1   4   42   45
# 2  78  178  728
# 3   6   76   46

# %% [markdown]
# getting our data out again:

# %%
arla['a']
# Out:
# 0     3
# 1     4
# 2    78
# 3     6
# Name: a, dtype: int64

# %%
d = arla['a'] #now we also define the a-column as a pandas-series
type(d)
# Out:
# pandas.Series

# %%
e = list(d)
e
# Out:
# [3, 4, 78, 6]

# %%
a == e #the double equal signs compares the two things
# Out:
# True

# %% [markdown]
# section 7.5.2 in LSP book is about dataframes

# %%
arla['row_mean'] = arla.mean(axis=1) 
#this function calculates the mean of every row.
#axis=1 means calculates row by row

# %%
arla
# Out:
#     a    b    c    row_mean
# 0   3   43   38   28.000000
# 1   4   42   45   30.333333
# 2  78  178  728  328.000000
# 3   6   76   46   42.666667

# %%
#name = pd.read_csv('/work/pathofCSVfileyouwanttoread')

# %%
df = pd.read_csv('/work/Experimental-Psycholinguistics-hello-Ethan-/Stroop-raw-over-the-years.csv')

# %%
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0             4.16        6.76          4.45         4.65  2015
# 1             4.35        7.73          4.78         4.46  2015
# 2             3.60        7.00          4.00         3.50  2015
# 3             3.90        9.03          4.60         6.30  2015
# 4             4.22        9.98          6.83         6.24  2015
# ..             ...         ...           ...          ...   ...
# 200           4.77       10.00          5.66         6.24  2025
# 201           4.61       12.80          6.87         9.55  2025
# 202           4.79       10.72          5.64         7.25  2025
# 203           4.41        8.87          6.70         6.70  2025
# 204           5.50        9.80          6.20        21.70  2025
#
# [205 rows x 5 columns]

# %%
df = df.drop(['Year'],axis=1)
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int
# 0             4.16        6.76          4.45         4.65
# 1             4.35        7.73          4.78         4.46
# 2             3.60        7.00          4.00         3.50
# 3             3.90        9.03          4.60         6.30
# 4             4.22        9.98          6.83         6.24
# ..             ...         ...           ...          ...
# 200           4.77       10.00          5.66         6.24
# 201           4.61       12.80          6.87         9.55
# 202           4.79       10.72          5.64         7.25
# 203           4.41        8.87          6.70         6.70
# 204           5.50        9.80          6.20        21.70
#
# [205 rows x 4 columns]

# %%
df['MeanRT'] = df.mean(axis=1)
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int   MeanRT
# 0             4.16        6.76          4.45         4.65   5.0050
# 1             4.35        7.73          4.78         4.46   5.3300
# 2             3.60        7.00          4.00         3.50   4.5250
# 3             3.90        9.03          4.60         6.30   5.9575
# 4             4.22        9.98          6.83         6.24   6.8175
# ..             ...         ...           ...          ...      ...
# 200           4.77       10.00          5.66         6.24   6.6675
# 201           4.61       12.80          6.87         9.55   8.4575
# 202           4.79       10.72          5.64         7.25   7.1000
# 203           4.41        8.87          6.70         6.70   6.6700
# 204           5.50        9.80          6.20        21.70  10.8000
#
# [205 rows x 5 columns]

# %%
df_sorted = df.sort_values(by=['Reading_NoInt'])

# %%
df_sorted
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int   MeanRT
# 77            2.83        6.29          4.03         4.15   4.3250
# 148           2.85        9.64          5.80         4.91   5.8000
# 149           2.93        7.40          5.28         3.28   4.7225
# 99            3.02        7.01          4.59         3.63   4.5625
# 10            3.10       10.49          5.34         3.62   5.6375
# ..             ...         ...           ...          ...      ...
# 120           7.06       12.44          8.15        11.85   9.8750
# 168           7.07        6.88          5.50         6.45   6.4750
# 191           7.31       28.32         24.62         7.46  16.9275
# 123           7.35        9.84          4.78         4.78   6.6875
# 115           8.16       12.33         11.71         7.23   9.8575
#
# [205 rows x 5 columns]

# %%
from statistics import mean
df['meanRT'] = mean(df['Reading_NoInt', 'Naming_Int', 'Naming_NoInt', 'Reading_In'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: ('Reading_NoInt', 'Naming_Int', 'Naming_NoInt', 'Reading_In')
#
# ...
