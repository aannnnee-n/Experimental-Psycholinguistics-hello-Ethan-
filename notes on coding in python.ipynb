# %% [markdown]
# # my first notebook
#
# in this noteboook I will learn abt the basic types of variables in python. they are:
#
# 1. strings
# 2. integers
# 3. floats
#
# (a variable is a thingX stored as variableNameY)
#
# _let's go_

# %% [markdown]
# ## strings

# %% [markdown]
# a string is a string of text. spaces and numbers are allowed
#
# strings are defined by quotation marks (either " or ')

# %%
fruit = "grapes"
fruit
# Out:
# 'grapes'

# %%
chips + fruit
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 chips + fruit
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# python sees ""2"" and sees the character, 2, not the value 2

# %%
# here I attempt to turn fruit into numbers
# "#" comments can also be used to block out code for a minute
fruit = "grapes"
# fruit = int(fruit)
fruit
fruit2 = "bananas"

fruit + fruit2
# Out:
# 'grapesbananas'

# %% [markdown]
# so strings cannot be added with numbers, integers and floats, but they can be added with other strings

# %% [markdown]
# ## integers

# %% [markdown]
# = whole numbers
#
# ie:

# %%
7 + 3
# Out:
# 10

# %% [markdown]
# using the snacks as variables:

# %%
chips = 2
cookies = 3
chips + cookies
# Out:
# 5

# %% [markdown]
# python now thinks: chips? I know what that is, that is an integer = 2, and the chips variable is now an integer variable

# %%
snacks = chips + cookies

# %%
type(snacks)
# Out:
# int

# %% [markdown]
# "type" is a function. it types variables, what kind they are

# %%
print(snacks)
# Out:
# 5

# %% [markdown]
# "print" prints the value of a variable

# %%
print(chips, cookies, snacks)
# Out:
# 2 3 5

# %% [markdown]
# to find the property of an obejct:

# %%
dir(fruit)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# that above is a list of things that we can do to fruit

# %%
fruit.upper()
# Out:
# 'GRAPES'

# %%
fruit.replace('a','@')
# Out:
# 'gr@pes'

# %% [markdown]
# it might be useful to change text to upper or lowercase bc python distinguishes between uppe rand lower case, so "The" is a different word from "the".
#
# to solve with you own data, you can also just have it be lower case from the start

# %% [markdown]
# ## floats

# %% [markdown]
# numbers with decimals
#
# python uses "." for decimals btw, watch out if like, excel uses ","

# %%
cookies = 3.2

# %%
cookies
# Out:
# 3.2

# %%
type(cookies)
# Out:
# float

# %% [markdown]
# we have now overwritten the integer variable "cookies" from 3 to 3.2, and python does not care to tell us this.
#
# this can be a problem with jupyter notebooks. if I think cookies is = 3.2, but go back and run the cell where it is stated to be 3, it will be overwritten again.
#
# to solve this, run every cell from the top one by one

# %% [markdown]
# ## sum up

# %% [markdown]
# we now know how to find out what variable we have,
#
# the difference between three variables,
#
# and some of the operations we can't and can't do
#
# everything in python is an object and how to find its properties
